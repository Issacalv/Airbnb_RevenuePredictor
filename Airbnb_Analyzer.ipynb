# %%
import pandas as pd
import os

# %%
NY_DATA = "Airbnb_NY_USA.csv"
NY_DF = pd.read_csv(NY_DATA)
NY_DF.head()
# Out:
#    listing_id                                     listing_name  listing_type  \
# 0       27047               Studio in the heart of South Beach  Entire condo
# 1       73621  CasaGrandeSouthBeach 4 room Beachfront Building  Entire condo
# 2      130905           Luxury Beachfront Condo on South Beach  Entire condo
# 3      186050              Beachfront- Direct Ocean View Condo  Entire condo
# 4      206580               Designer SoBe condo 1 blk to ocean  Entire condo
#
#      room_type                                    cover_photo_url  \
# 0  entire_home  https://a0.muscache.com/im/pictures/hosting/Ho...
# 1  entire_home  https://a0.muscache.com/im/pictures/miso/Hosti...
# 2  entire_home  https://a0.muscache.com/im/pictures/53c044c9-c...
# 3  entire_home  https://a0.muscache.com/im/pictures/45599688/7...
# 4  entire_home  https://a0.muscache.com/im/pictures/1944929/f1...
#
#    photos_count  host_id        host_name cohost_ids cohost_names  ...  \
# ...

# %% [markdown]
# # Dataset information:
# | Field                          | Type                | Description                                                                          | keep or remove |
# |--------------------------------|---------------------|--------------------------------------------------------------------------------------|----------------|
# | listing_id                     | long                | Unique identifier for the listing                                                    |K              |
# | listing_name                   | string              | Title of the listing                                                                 |R                |
# | listing_type                   | string              | Type of property (e.g., apartment, house, villa)                                     |K                |
# | room_type                      | string              | Type of room (e.g., entire home, private room)                                       |K                |
# | cover_photo_url                | string              | URL of the main listing photo                                                        |R                |
# | photos_count                   | integer             | Number of photos available for the listing                                           |K                |
# | host_id                        | long                | Unique identifier for the host                                                       |R                |
# | host_name                      | string              | Name of the host                                                                     |R                |
# | cohost_ids                     | string              | Ids of co-hosts associated with the listing                                          |R                |
# | cohost_names                   | string              | Names of co-hosts associated with the listing                                        |R                |
# | superhost                      | boolean             | Whether the host is a superhost                                                      |K                |
# | country                        | string              | Country where the listing is located                                                 |R (Since this is for US)                |
# | state                          | string              | State or province where the listing is located                                       |R                |
# | city                           | string              | City where the listing is located                                                    |R                |
# | latitude                       | decimal(10,4)       | Geographical latitude coordinate                                                      |?                |
# | longitude                      | decimal(10,4)       | Geographical longitude coordinate                                                    |?                |
# | guests                         | integer             | Maximum number of guests allowed                                                     |K                |
# | bedrooms                       | integer             | Number of bedrooms available                                                         |K                |
# | beds                           | integer             | Number of beds available                                                             |K                |
# | baths                          | decimal(4,1)        | Number of bathrooms available                                                        |K                |
# | registration                   | boolean             | Indicates if the listing has a registration number                                   |R                |
# | amenities                      | string              | List of amenities offered                                                            |K                |
# | instant_book                   | boolean             | Whether the listing can be booked instantly                                          |K                |
# | professional_management        | boolean             | Whether the listing is professionally managed                                        |K                |
# | min_nights                     | integer             | Minimum number of nights required to book                                            |K                |
# | cancellation_policy            | string              | Type of cancellation policy offered                                                  |R                |
# | currency                       | string              | Currency used for pricing                                                            |K                |
# | cleaning_fee                   | integer             | The cleaning fee for the listing                                                     |K                |
# | extra_guest_fee                | integer             | Fee for each extra guest                                                             |K                |
# | num_reviews                    | integer             | Total number of reviews received                                                     |K                |
# | rating_overall                 | double              | Overall rating score                                                                  |K                |
# | rating_accuracy                | double              | Rating score for listing accuracy                                                    |K                |
# | rating_checkin                 | double              | Rating score for check-in experience                                                 |K                |
# | rating_cleanliness             | double              | Rating score for cleanliness                                                         |K                |
# | rating_communication           | double              | Rating score for host communication                                                  |K                |
# | rating_location                | double              | Rating score for location                                                            |K                |
# | rating_value                   | double              | Rating score for value                                                               |K                |
# | ttm_revenue                    | double              | Total revenue in trailing twelve months                                              |R               |
# | ttm_revenue_native             | double              | Total revenue in native currency in trailing twelve months                           |K                |
# | ttm_avg_rate                   | double              | Average daily rate in trailing twelve months                                         |R                |
# | ttm_avg_rate_native            | double              | Average daily rate in native currency in trailing twelve months                      |K                |
# | ttm_occupancy                  | double              | Occupancy rate in trailing twelve months                                             |K                |
# | ttm_adjusted_occupancy         | double              | Adjusted occupancy rate in trailing twelve months, excluding owner-blocked days      |K                |
# | ttm_revpar                     | double              | Revenue per available room (RevPAR) in trailing twelve months                        |R                |
# | ttm_revpar_native              | double              | Revenue per available room (RevPAR) in native currency in trailing twelve months     |K                |
# | ttm_adjusted_revpar            | double              | Adjusted RevPAR in trailing twelve months                                            |R                |
# | ttm_adjusted_revpar_native     | double              | Adjusted RevPAR in native currency in trailing twelve months                         |K                |
# | ttm_reserved_days              | long                | Number of booked/reserved days in trailing twelve months                             |R                |
# | ttm_blocked_days               | long                | Number of host-blocked days in trailing twelve months                                |R                |
# | ttm_available_days             | long                | Number of available days in trailing twelve months                                   |R                |
# | ttm_total_days                 | long                | Total number of days in trailing twelve months (reserved + available)                |R                |
# | l90d_revenue                   | double              | Revenue in the last 90 days                                                          |R                |
# | l90d_revenue_native            | double              | Revenue in native currency in the last 90 days                                       |R                |
# | l90d_avg_rate                  | double              | Average daily rate in the last 90 days                                               |R                |
# | l90d_avg_rate_native           | double              | Average daily rate in native currency in the last 90 days                            |R                |
# | l90d_occupancy                 | double              | Occupancy rate in the last 90 days                                                   |R                |
# | l90d_adjusted_occupancy        | double              | Adjusted occupancy rate in the last 90 days                                          |R                |
# | l90d_revpar                    | double              | RevPAR in the last 90 days                                                           |R                |
# | l90d_revpar_native             | double              | RevPAR in native currency in the last 90 days                                        |R                |
# | l90d_adjusted_revpar           | double              | Adjusted RevPAR in the last 90 days                                                  |R                |
# | l90d_adjusted_revpar_native    | double              | Adjusted RevPAR in native currency in the last 90 days                               |R                |
# | l90d_reserved_days             | long                | Number of reserved days in the last 90 days                                          |R                |
# | l90d_blocked_days              | long                | Number of blocked days in the last 90 days                                           |R                |
# | l90d_available_days            | long                | Number of available days in the last 90 days                                         |R                |
# | l90d_total_days                | long                | Total number of days considered in the last 90 days period                           |R                |

# %%
NY_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 62 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   listing_id                   300 non-null    int64
#  1   listing_name                 300 non-null    object
#  2   listing_type                 300 non-null    object
#  3   room_type                    300 non-null    object
#  4   cover_photo_url              300 non-null    object
#  5   photos_count                 300 non-null    int64
#  6   host_id                      300 non-null    int64
#  7   host_name                    296 non-null    object
#  8   cohost_ids                   28 non-null     object
#  9   cohost_names                 28 non-null     object
#  10  superhost                    300 non-null    bool
#  11  latitude                     300 non-null    float64
#  12  longitude                    300 non-null    float64
# ...

# %%
def df_unique_values(df, MAX_VALUES=10, col=None):

    print("\n================== UNIQUE VALUES REPORT ==================\n")

    if col is not None:
        if col not in df.columns:
            print(f"Column '{col}' does not exist in the DataFrame.")
            return
        
        unique_vals = df[col].unique()
        num_unique = len(unique_vals)

        print(f"Column Name: {col}")

        if num_unique > MAX_VALUES:
            print(f"  Unique Values ({num_unique} total): showing first {MAX_VALUES}")
            print(f"  {list(unique_vals[:MAX_VALUES])}")
        else:
            print(f"  Unique Values ({num_unique} total):")
            print(f"  {unique_vals}")

        print("\n  Value Counts:")
        print(df[col].value_counts().head(MAX_VALUES))

        print("\n====================== END REPORT ======================\n")
        return
    
    for col in df.columns:
        print(f"Column Name: {col}")
        unique_vals = df[col].unique()
        num_unique = len(unique_vals)

        if num_unique > MAX_VALUES:
            print(f"  Unique Values ({num_unique} total): showing first {MAX_VALUES}")
            print(f"  {list(unique_vals[:MAX_VALUES])}")
        else:
            print(f"  Unique Values ({num_unique} total):")
            print(f"  {unique_vals}")

        print("\n  Value Counts:")
        print(df[col].value_counts().head(MAX_VALUES))
        print("\n--------------------------------------------------------------\n")

    print("========================== END REPORT =========================\n")

# %%
def drop_rows(df, col, target_rows, save_to_csv=True, csv_file="Airbnb_NY_USA_filtered.csv", csv_folder="CSV Files"):
    if not isinstance(target_rows, (list, tuple, set)):
        target_rows = [target_rows]

    df_filtered = df[~df[col].isin(target_rows)]

    if save_to_csv:
        if not os.path.exists(csv_folder):
            os.makedirs(csv_folder)

        csv_path = os.path.join(csv_folder, csv_file)

        if not os.path.exists(csv_path):
            df_filtered.to_csv(csv_path, index=False)
            print(f"New csv file created: {csv_file}")
        else:
            print(f"CSV file already exists at: {csv_path}")

    return df_filtered


def drop_cols(df, cols_to_drop, save_to_csv = True, csv_file="Airbnb_NY_USA_filtered.csv", csv_folder = "CSV FILES"):
    df_filtered = df.drop(columns = cols_to_drop)

    if save_to_csv:
        if not os.path.exists(csv_folder):
            os.makedirs(csv_folder)

        csv_path = os.path.join(csv_folder, csv_file)

        if not os.path.exists(csv_path):
            df_filtered.to_csv(csv_path, index=False)
            print(f"New csv file name {csv_file}")
        else:
            print(f"csv file already exists at {csv_path}")

    return df_filtered

# %%
cols_to_drop = [
    "listing_name",
    "cover_photo_url",
    "host_id",
    "host_name",
    "cohost_ids",
    "cohost_names",
    "registration",
    "cancellation_policy",
    "ttm_revenue",
    "ttm_avg_rate",
    "ttm_revpar",
    "ttm_adjusted_revpar",
    "ttm_reserved_days",
    "ttm_blocked_days",
    "ttm_available_days",
    "ttm_total_days",
    "l90d_revenue",
    "l90d_revenue_native",
    "l90d_avg_rate",
    "l90d_avg_rate_native",
    "l90d_occupancy",
    "l90d_adjusted_occupancy",
    "l90d_revpar",
    "l90d_revpar_native",
    "l90d_adjusted_revpar",
    "l90d_adjusted_revpar_native",
    "l90d_reserved_days",
    "l90d_blocked_days",
    "l90d_available_days",
    "l90d_total_days"
]

# %%
NY_DF = drop_cols(NY_DF, cols_to_drop, save_to_csv= False)
NY_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   listing_id                  300 non-null    int64
#  1   listing_type                300 non-null    object
#  2   room_type                   300 non-null    object
#  3   photos_count                300 non-null    int64
#  4   superhost                   300 non-null    bool
#  5   latitude                    300 non-null    float64
#  6   longitude                   300 non-null    float64
#  7   guests                      288 non-null    float64
#  8   bedrooms                    222 non-null    float64
#  9   beds                        299 non-null    float64
#  10  baths                       300 non-null    float64
#  11  amenities                   300 non-null    object
#  12  instant_book                283 non-null    object
# ...

# %%
df_unique_values(NY_DF)
# Out:
# ================== UNIQUE VALUES REPORT ==================
#
# Column Name: listing_id
#   Unique Values (300 total): showing first 10
#   [np.int64(27047), np.int64(73621), np.int64(130905), np.int64(186050), np.int64(206580), np.int64(227402), np.int64(228055), np.int64(232005), np.int64(235946), np.int64(271596)]
#
#   Value Counts:
# listing_id
# 11242057    1
# 27047       1
# 73621       1
# 130905      1
# 186050      1
# 206580      1
# 227402      1
# 228055      1
# 232005      1
# 235946      1
# Name: count, dtype: int64
#
# --------------------------------------------------------------
#
# Column Name: listing_type
#   Unique Values (15 total): showing first 10
#   ['Entire condo', 'Entire rental unit', 'Private room in condo', 'Room in aparthotel', 'Entire serviced apartment', 'Private room in rental unit', 'Room in boutique hotel', 'Entire townhouse', 'Entire vacation home', 'Private room in bed and breakfast']
#
#   Value Counts:
# listing_type
# ...
